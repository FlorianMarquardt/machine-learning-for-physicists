# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/FlorianMarquardt/machine-learning-for-physicists/blob/master/2024/08_Tutorial_BoltzmannMachine.ipynb)

# %% [markdown]
# # Tutorial: Boltzmann Machines
#
# This shows how to train a Boltzmann machine, to sample from an observed probability distribution.

# %% [markdown]
# Example code for the lecture series "Machine Learning for Physicists" by Florian Marquardt
#
# Lecture 9, Tutorial (this is discussed in session 9)
#
# See https://machine-learning-for-physicists.org and the current course website linked there!
#
# This notebook is distributed under the Attribution-ShareAlike 4.0 International (CC BY-SA 4.0) license:
#
# https://creativecommons.org/licenses/by-sa/4.0/

# %% [markdown]
# This notebook shows how to:
# - use a Boltzmann machine to sample from an observed high-dimensional probability distribution (e.g. produce images that look similar to observed training images)
# - training images: blocks of ones and zeros

# %% [markdown]
# ![image](bm-fig01.png)

# %%
import numpy as np
import jax.numpy as jnp
import jax
import matplotlib.pyplot as plt
import matplotlib
matplotlib.rcParams['figure.dpi']=300 # highres display

from IPython.display import clear_output
from time import sleep

# %% [markdown]
# ![image](bm-fig02.png)

# %% [markdown]
# **One Boltzmann step:**
# - BoltzmannStep(v,b,w,random_key) performs step from $v_i$ to $h_j$
# - obtain $h_j=1$ with probability $\frac{1}{1+e^{-z_j}}$ with $z_j = b_j + \sum_i v_i w_{i,j}$
# - Boltzmann step from h_j to v_i is obtained in the same way; only w needs to be transposed
#
# **Boltzmann sequence:**
# - BoltzmannSequence(v,a,b,w,random_key,drop_h_prime=False) performs Boltzmann steps from $v_i$ to $h_j$ to $v_i'$ to $h_j'$
#
# **Training:**
# - trainStep(v,a,b,w,random_key) updates parameters
# - for a cross-entropy cost function, the gradients can be computed as the following expectation values
#     - $\delta w_{i,j} = \eta ( \langle v_i h_j\rangle - \langle v'_i h'_j\rangle )$
#     - $\delta a_i  = \eta ( \langle v_i\rangle - \langle v'_i\rangle)$
#     - $\delta b_j  = \eta ( \langle h_j\rangle - \langle h'_j\rangle)$
#
# see https://scipost.org/SciPostPhysLectNotes.29 (page 27)

# %%
def BoltzmannStep(v,b,w,random_key):
    """
    Perform a single step of the Markov chain,
    going from visible units v to hidden units h,
    according to biases b and weights w.
    
    z_j = b_j + sum_i v_i w_ij
    
    and P(h_j=1|v) = 1/(exp(-z_j)+1)
    
    Note: you can go from h to v, by inserting
    instead of v the h, instead of b the a, and
    instead of w the transpose of w
    """
    batchsize=jnp.shape(v)[0]
    hidden_dim=jnp.shape(w)[1]
    z=b+jnp.dot(v,w)
    P=1/(jnp.exp(-z)+1)
    # now, the usual trick to obtain 0 or 1 according
    # to a given probability distribution:
    # just produce uniform (in [0,1]) random numbers and
    # check whether they are below the cutoff given by P
    random_key,new_key = jax.random.split(random_key)
    p=jax.random.uniform(new_key,shape=[batchsize,hidden_dim])
    return new_key, jnp.array(p<=P,dtype='int')
    
def BoltzmannSequence(v,a,b,w,random_key,drop_h_prime=False):
    """
    Perform one sequence of steps v -> h -> v' -> h'
    of a Boltzmann machine, with the given
    weights w and biases a and b!
    
    All the arrays have a shape [batchsize,num_neurons]
    (where num_neurons is num_visible for v and
    num_hidden for h)
    
    You can set drop_h_prime to True if you want to
    use this routine to generate arbitrarily long sequences
    by calling it repeatedly (then don't use h')
    Returns: v,h,v',h'
    """
    random_key, h = BoltzmannStep(v,b,w,random_key)
    random_key, v_prime = BoltzmannStep(h,a,np.transpose(w),random_key)
    if not drop_h_prime:
        random_key, h_prime = BoltzmannStep(v_prime,b,w,random_key)
    else:
        h_prime = np.zeros(np.shape(h))
    return random_key,v,h,v_prime,h_prime

def trainStep(v,a,b,w,random_key):
    """
    Given a set of randomly selected training samples
    v (of shape [batchsize,num_neurons_visible]), 
    and given biases a,b and weights w: update
    those biases and weights according to the
    contrastive-divergence update rules:
    
    delta w_ij = eta ( <v_i h_j> - <v'_i h'_j> )
    delta a_i  = eta ( <v_i> - <v'_i>)
    delta b_j  = eta ( <h_j> - <h'_j>)
    
    Returns delta_a, delta_b, delta_w, but without the eta factor!
    It is up to you to update a,b,w!
    """
    random_key,v,h,v_prime,h_prime=BoltzmannSequence(v,a,b,w,random_key)
    return( random_key,
            jnp.average(v,axis=0)-jnp.average(v_prime,axis=0) ,
            jnp.average(h,axis=0)-jnp.average(h_prime,axis=0) ,
            jnp.average(v[:,:,None]*h[:,None,:],axis=0)-
               jnp.average(v_prime[:,:,None]*h_prime[:,None,:],axis=0) )

# %%
def produce_samples_random_segment(batchsize,num_visible,random_key,max_distance=3):
    """
    Produce 'batchsize' samples, of length num_visible.
    Returns array v of shape [batchsize,num_visible]
    
    This here: produces randomly placed segments of
    size 2*max_distance.
    """
    random_key,new_key = jax.random.split(random_key)
    random_pos=num_visible * jax.random.uniform(new_key,shape=(batchsize,))

    tmp=jnp.arange(0,num_visible)
    
    return new_key, (jnp.array( jnp.abs(tmp[None,:]-random_pos[:,None])<=max_distance, dtype='int' ))

# %%
# Now: the training

num_visible=20
num_hidden=10
batchsize=50
eta=0.1
nsteps=500
skipsteps=10

random_key = jax.random.key(42) # first 'key', like setting a random seed

random_key,new_key = jax.random.split(random_key)
a=jax.random.uniform(new_key,shape=(num_visible,))

random_key,new_key = jax.random.split(random_key)
b=jax.random.uniform(new_key,shape=(num_hidden,))

random_key,new_key = jax.random.split(random_key)
w=jax.random.uniform(new_key,shape=(num_visible,num_hidden))

test_samples=jnp.zeros([num_visible,nsteps])

for j in range(nsteps):
    random_key, v=produce_samples_random_segment(batchsize,num_visible,random_key)
    random_key,da,db,dw=trainStep(v,a,b,w,random_key)
    a+=eta*da
    b+=eta*db
    w+=eta*dw
    test_samples=test_samples.at[:,j].set(v[0,:])
    if j%skipsteps==0 or j==nsteps-1:
        clear_output(wait=True)
        plt.figure(figsize=(10,3))
        plt.imshow(test_samples,origin='lower',aspect='auto',interpolation='none')
        plt.axis('off')
        plt.show()

## visualisation shows first sample of training batch

# %%
# Now: visualize the typical samples generated (from some starting point)
# run several times to continue this. It basically is a random walk
# through the space of all possible configurations, hopefully according
# to the probability distribution that has been trained!

nsteps=100
test_samples=jnp.zeros([num_visible,nsteps])

v_prime=jnp.zeros(num_visible)
h=jnp.zeros(num_hidden)
h_prime=jnp.zeros(num_hidden)

for j in range(nsteps):
    random_key,v,h,v_prime,h_prime=BoltzmannSequence(v,a,b,w,random_key,drop_h_prime=True) # step from v via h to v_prime!
    test_samples = test_samples.at[:,j].set(v[0,:])
    v=jnp.copy(v_prime) # use the new v as a starting point for next step!
    if j%skipsteps==0 or j==nsteps-1:
        clear_output(wait=True)
        plt.imshow(test_samples,origin='lower',interpolation='none')
        plt.show()

# %%
# Now show the weight matrix

plt.figure(figsize=(0.2*num_visible,0.2*num_hidden))
plt.imshow(w,origin='lower',aspect='auto')
plt.show()

# %% [markdown]
# # Tutorial: train on differently shaped samples (e.g. a bar with both random position and random width)
#
# ...or two bars, located always at the same distance!

# %% [markdown]
# # Homework: train on MNIST images!
#
# Here the visible units must be a flattened version of the images, something like
#
# v=jnp.reshape(image,[batchsize,widh*height])
#
# ...if image is of shape [batchsize,width,height], meaning an array holding the pixel values for all images in a batch!
#
# ...to plot the results, you would use
#
# jnp.reshape(v,[batchsize,width,height])
#
# to get back to the image format!
